# %% [markdown]
# ### Gathering MRT data

# %%
import pandas as pd
pd.set_option("max_columns", None)
import numpy as np
import requests
import time

# %%
df_mrt = pd.read_excel("MRT-Stations.xlsx")
df_mrt.head()
# Out:
#        Code   Station Name
# 0  NS1 EW24    Jurong East
# 1       NS2    Bukit Batok
# 2       NS3   Bukit Gombak
# 3   NS4 BP1  Choa Chu Kang
# 4       NS5        Yew Tee

# %%
mrt_address_list = df_mrt["Station Name"] + " MRT"
mrt_address_list.head()
# Out:
# 0      Jurong East MRT
# 1      Bukit Batok MRT
# 2     Bukit Gombak MRT
# 3    Choa Chu Kang MRT
# 4          Yew Tee MRT
# Name: Station Name, dtype: object

# %%
def get_coordinate(address):
    response = requests.get(f"https://developers.onemap.sg/commonapi/search?searchVal={address}&returnGeom=Y&getAddrDetails=Y&pageNum=1").json()
    return response["results"][0]["POSTAL"], response["results"][0]["LATITUDE"], response["results"][0]["LONGITUDE"]

# %%
count = 0
mrt_coordinates_list = []
mrt_error_list = []

for address in mrt_address_list:
    try:
        coords = get_coordinate(address)
        mrt_coordinates_list.append(coords)
        count += 1
        time.sleep(0.3)
        print(f"{count} of {len(mrt_address_list)} datapoints obtained. {len(mrt_error_list)} errors encountered.")
                        
    except:
        mrt_error_list.append(address)
        mrt_coordinates_list.append(None)
        print(f"{len(mrt_error_list)} errors encountered.")
        
print(f"Completed. There were {len(mrt_error_list)} errors.")
# Out:
# 1 of 122 datapoints obtained. 0 errors encountered.
# 2 of 122 datapoints obtained. 0 errors encountered.
# 3 of 122 datapoints obtained. 0 errors encountered.
# 4 of 122 datapoints obtained. 0 errors encountered.
# 5 of 122 datapoints obtained. 0 errors encountered.
# 6 of 122 datapoints obtained. 0 errors encountered.
# 7 of 122 datapoints obtained. 0 errors encountered.
# 8 of 122 datapoints obtained. 0 errors encountered.
# 9 of 122 datapoints obtained. 0 errors encountered.
# 10 of 122 datapoints obtained. 0 errors encountered.
# 11 of 122 datapoints obtained. 0 errors encountered.
# 12 of 122 datapoints obtained. 0 errors encountered.
# 13 of 122 datapoints obtained. 0 errors encountered.
# 14 of 122 datapoints obtained. 0 errors encountered.
# 15 of 122 datapoints obtained. 0 errors encountered.
# 16 of 122 datapoints obtained. 0 errors encountered.
# 17 of 122 datapoints obtained. 0 errors encountered.
# 18 of 122 datapoints obtained. 0 errors encountered.
# 19 of 122 datapoints obtained. 0 errors encountered.
# 20 of 122 datapoints obtained. 0 errors encountered.
# 21 of 122 datapoints obtained. 0 errors encountered.
# 22 of 122 datapoints obtained. 0 errors encountered.
# 23 of 122 datapoints obtained. 0 errors encountered.
# 24 of 122 datapoints obtained. 0 errors encountered.
# 25 of 122 datapoints obtained. 0 errors encountered.
# 26 of 122 datapoints obtained. 0 errors encountered.
# 27 of 122 datapoints obtained. 0 errors encountered.
# 28 of 122 datapoints obtained. 0 errors encountered.
# 29 of 122 datapoints obtained. 0 errors encountered.
# 30 of 122 datapoints obtained. 0 errors encountered.
# 31 of 122 datapoints obtained. 0 errors encountered.
# 32 of 122 datapoints obtained. 0 errors encountered.
# 33 of 122 datapoints obtained. 0 errors encountered.
# 34 of 122 datapoints obtained. 0 errors encountered.
# 35 of 122 datapoints obtained. 0 errors encountered.
# 36 of 122 datapoints obtained. 0 errors encountered.
# 37 of 122 datapoints obtained. 0 errors encountered.
# 38 of 122 datapoints obtained. 0 errors encountered.
# 39 of 122 datapoints obtained. 0 errors encountered.
# 40 of 122 datapoints obtained. 0 errors encountered.
# 41 of 122 datapoints obtained. 0 errors encountered.
# 42 of 122 datapoints obtained. 0 errors encountered.
# 43 of 122 datapoints obtained. 0 errors encountered.
# 44 of 122 datapoints obtained. 0 errors encountered.
# 45 of 122 datapoints obtained. 0 errors encountered.
# 46 of 122 datapoints obtained. 0 errors encountered.
# 47 of 122 datapoints obtained. 0 errors encountered.
# 48 of 122 datapoints obtained. 0 errors encountered.
# 49 of 122 datapoints obtained. 0 errors encountered.
# 50 of 122 datapoints obtained. 0 errors encountered.
# 51 of 122 datapoints obtained. 0 errors encountered.
# 52 of 122 datapoints obtained. 0 errors encountered.
# 53 of 122 datapoints obtained. 0 errors encountered.
# 54 of 122 datapoints obtained. 0 errors encountered.
# 55 of 122 datapoints obtained. 0 errors encountered.
# 56 of 122 datapoints obtained. 0 errors encountered.
# 57 of 122 datapoints obtained. 0 errors encountered.
# 58 of 122 datapoints obtained. 0 errors encountered.
# 59 of 122 datapoints obtained. 0 errors encountered.
# 60 of 122 datapoints obtained. 0 errors encountered.
# 61 of 122 datapoints obtained. 0 errors encountered.
# 62 of 122 datapoints obtained. 0 errors encountered.
# 63 of 122 datapoints obtained. 0 errors encountered.
# 64 of 122 datapoints obtained. 0 errors encountered.
# 65 of 122 datapoints obtained. 0 errors encountered.
# 66 of 122 datapoints obtained. 0 errors encountered.
# 67 of 122 datapoints obtained. 0 errors encountered.
# 68 of 122 datapoints obtained. 0 errors encountered.
# 69 of 122 datapoints obtained. 0 errors encountered.
# 70 of 122 datapoints obtained. 0 errors encountered.
# 71 of 122 datapoints obtained. 0 errors encountered.
# 72 of 122 datapoints obtained. 0 errors encountered.
# 73 of 122 datapoints obtained. 0 errors encountered.
# 74 of 122 datapoints obtained. 0 errors encountered.
# 75 of 122 datapoints obtained. 0 errors encountered.
# 76 of 122 datapoints obtained. 0 errors encountered.
# 77 of 122 datapoints obtained. 0 errors encountered.
# 78 of 122 datapoints obtained. 0 errors encountered.
# 79 of 122 datapoints obtained. 0 errors encountered.
# 80 of 122 datapoints obtained. 0 errors encountered.
# 81 of 122 datapoints obtained. 0 errors encountered.
# 82 of 122 datapoints obtained. 0 errors encountered.
# 83 of 122 datapoints obtained. 0 errors encountered.
# 84 of 122 datapoints obtained. 0 errors encountered.
# 85 of 122 datapoints obtained. 0 errors encountered.
# 86 of 122 datapoints obtained. 0 errors encountered.
# 87 of 122 datapoints obtained. 0 errors encountered.
# 88 of 122 datapoints obtained. 0 errors encountered.
# 89 of 122 datapoints obtained. 0 errors encountered.
# 90 of 122 datapoints obtained. 0 errors encountered.
# 91 of 122 datapoints obtained. 0 errors encountered.
# 92 of 122 datapoints obtained. 0 errors encountered.
# 93 of 122 datapoints obtained. 0 errors encountered.
# 94 of 122 datapoints obtained. 0 errors encountered.
# 95 of 122 datapoints obtained. 0 errors encountered.
# 96 of 122 datapoints obtained. 0 errors encountered.
# 97 of 122 datapoints obtained. 0 errors encountered.
# 98 of 122 datapoints obtained. 0 errors encountered.
# 99 of 122 datapoints obtained. 0 errors encountered.
# 100 of 122 datapoints obtained. 0 errors encountered.
# 101 of 122 datapoints obtained. 0 errors encountered.
# 102 of 122 datapoints obtained. 0 errors encountered.
# 103 of 122 datapoints obtained. 0 errors encountered.
# 104 of 122 datapoints obtained. 0 errors encountered.
# 105 of 122 datapoints obtained. 0 errors encountered.
# 106 of 122 datapoints obtained. 0 errors encountered.
# 107 of 122 datapoints obtained. 0 errors encountered.
# 108 of 122 datapoints obtained. 0 errors encountered.
# 109 of 122 datapoints obtained. 0 errors encountered.
# 110 of 122 datapoints obtained. 0 errors encountered.
# 111 of 122 datapoints obtained. 0 errors encountered.
# 112 of 122 datapoints obtained. 0 errors encountered.
# 113 of 122 datapoints obtained. 0 errors encountered.
# 114 of 122 datapoints obtained. 0 errors encountered.
# 115 of 122 datapoints obtained. 0 errors encountered.
# 116 of 122 datapoints obtained. 0 errors encountered.
# 117 of 122 datapoints obtained. 0 errors encountered.
# 118 of 122 datapoints obtained. 0 errors encountered.
# 119 of 122 datapoints obtained. 0 errors encountered.
# 120 of 122 datapoints obtained. 0 errors encountered.
# 121 of 122 datapoints obtained. 0 errors encountered.
# 122 of 122 datapoints obtained. 0 errors encountered.
# Completed. There were 0 errors.

# %%
df_mrt_coordinates = pd.DataFrame(mrt_coordinates_list, columns = ["Postal", "Latitude", "Longitude"])
df_mrt_coordinates.head()
# Out:
#    Postal          Latitude         Longitude
# 0  609690  1.33315281585758  103.742286332403
# 1  659958  1.34903331201636  103.749566478309
# 2  659083  1.35861159094192  103.751790910733
# 3  689810  1.38536316540225  103.744370779756
# 4  689715  1.39753506936297  103.747405150236

# %%
#Join obtained coords with df_mrt
df_mrt = df_mrt.join(df_mrt_coordinates)
df_mrt = df_mrt.drop(columns = ["Code"])
df_mrt.head()
# Out:
#     Station Name  Postal          Latitude         Longitude
# 0    Jurong East  609690  1.33315281585758  103.742286332403
# 1    Bukit Batok  659958  1.34903331201636  103.749566478309
# 2   Bukit Gombak  659083  1.35861159094192  103.751790910733
# 3  Choa Chu Kang  689810  1.38536316540225  103.744370779756
# 4        Yew Tee  689715  1.39753506936297  103.747405150236

# %%
#df_mrt.to_csv("MRT-with-coordinates.csv", index=False)
df_mrt = pd.read_csv("MRT-with-coordinates.csv")

# %% [markdown]
# ### Obtaining Nearest MRT Station and Distance to Station

# %%
df_hdb = pd.read_csv("Resale-list-with-coordinates-and-height.csv")
df_hdb.head()
# Out:
#      month        town flat_type block        street_name  floor_area_sqm  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10            44.0
# 1  2017-05  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10            44.0
# 2  2018-03  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10            44.0
# 3  2018-03  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10            44.0
# 4  2018-05  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10            44.0
#
#   flat_model  lease_commence_date     remaining_lease  resale_price  Postal  \
# 0   Improved                 1979  61 years 04 months      232000.0  560406
# 1   Improved                 1979   61 years 01 month      235000.0  560406
# 2   Improved                 1979  60 years 02 months      202000.0  560406
# 3   Improved                 1979  60 years 02 months      210000.0  560406
# 4   Improved                 1979   60 years 01 month      220000.0  560406
#
#    Latitude  Longitude  max_floor_lvl  height_index
# 0  1.362005  103.85388             12           4.0
# 1  1.362005  103.85388             12           4.0
# 2  1.362005  103.85388             12           1.0
# 3  1.362005  103.85388             12           1.0
# 4  1.362005  103.85388             12           3.0

# %%
df_hdb.shape[0]
# Out:
# 134393

# %%
df_hdb.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# remaining_lease         object
# resale_price           float64
# Postal                   int64
# Latitude               float64
# Longitude              float64
# max_floor_lvl            int64
# height_index           float64
# dtype: object

# %%
df_mrt.dtypes
# Out:
# Station Name     object
# Postal            int64
# Latitude        float64
# Longitude       float64
# dtype: object

# %%
df_hdb.Postal = pd.to_numeric(df_hdb.Postal, errors = "coerce")
df_hdb.Latitude = df_hdb.Latitude.astype(float)
df_hdb.Longitude = df_hdb.Longitude.astype(float)
df_mrt.Latitude = df_mrt.Latitude.astype(float)
df_mrt.Longitude = df_mrt.Longitude.astype(float)
print(df_hdb.dtypes)
print(df_mrt.dtypes)
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# remaining_lease         object
# resale_price           float64
# Postal                   int64
# Latitude               float64
# Longitude              float64
# max_floor_lvl            int64
# height_index           float64
# dtype: object
# Station Name     object
# Postal            int64
# Latitude        float64
# Longitude       float64
# dtype: object

# %%
#Using sklearn's haversine distance function to obtain nearest MRT station and distance to the station

from sklearn.metrics.pairwise import haversine_distances

nearest_station = []
shortest_distance = []
for lat, long in zip(df_hdb["Latitude"], df_hdb["Longitude"]):
    latlong = [[lat,long]]
    result = haversine_distances(np.radians(latlong), np.radians(df_mrt[["Latitude", "Longitude"]])) * 6371000/1000
    distance = np.amin(result)
    station = np.where(result == distance)[1][0]
    shortest_distance.append(round(distance,2))
    nearest_station.append(station)
df_hdb['Nearest_Station'] = nearest_station
df_hdb['Distance_to_MRT'] = shortest_distance

# %%
df_hdb.tail()
# Out:
#           month       town flat_type block      street_name  floor_area_sqm  \
# 134388  2022-08  WOODLANDS    4 ROOM  693A  WOODLANDS AVE 6            92.0
# 134389  2022-08  WOODLANDS    4 ROOM  691A  WOODLANDS DR 73            93.0
# 134390  2022-08  WOODLANDS    4 ROOM  784B   WOODLANDS RISE            93.0
# 134391  2022-08  WOODLANDS    4 ROOM  784B   WOODLANDS RISE            93.0
# 134392  2022-08  WOODLANDS    5 ROOM  783A   WOODLANDS RISE           113.0
#
#        flat_model  lease_commence_date     remaining_lease  resale_price  \
# 134388    Model A                 2018  95 years 03 months      540000.0
# 134389    Model A                 2018  94 years 11 months      555000.0
# 134390    Model A                 2018            95 years      538000.0
# 134391    Model A                 2018            95 years      535000.0
# 134392   Improved                 2018   95 years 01 month      605888.0
#
#         Postal  Latitude   Longitude  max_floor_lvl  height_index  \
# 134388  731693  1.438782  103.803708             13           3.0
# 134389  731691  1.440304  103.806660             14           3.0
# 134390  732784  1.445521  103.804854             14           5.0
# 134391  732784  1.445521  103.804854             14           2.0
# 134392  731783  1.447417  103.803742             16           6.0
#
#         Nearest_Station  Distance_to_MRT
# 134388                8             0.36
# 134389                8             0.63
# 134390                8             0.70
# 134391                8             0.70
# 134392                8             0.82

# %%
df_mrt.head()
# Out:
#     Station Name  Postal  Latitude   Longitude
# 0    Jurong East  609690  1.333153  103.742286
# 1    Bukit Batok  659958  1.349033  103.749566
# 2   Bukit Gombak  659083  1.358612  103.751791
# 3  Choa Chu Kang  689810  1.385363  103.744371
# 4        Yew Tee  689715  1.397535  103.747405

# %%
#Dropping MRT coordinates as there is no further need for them
df_mrt = df_mrt.drop(columns = ["Postal", "Latitude", "Longitude"])
#Create a new column mirroring the index to join both dataframes
df_mrt["IndexCopy"] = df_mrt.index
df_mrt.head()
# Out:
#     Station Name  IndexCopy
# 0    Jurong East          0
# 1    Bukit Batok          1
# 2   Bukit Gombak          2
# 3  Choa Chu Kang          3
# 4        Yew Tee          4

# %%
#Join both dataframes
df_final = df_hdb.merge(df_mrt, left_on= df_hdb["Nearest_Station"], right_on = df_mrt["IndexCopy"])
df_final.head()
# Out:
#    key_0    month        town flat_type block        street_name  \
# 0     14  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10
# 1     14  2017-05  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10
# 2     14  2018-03  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10
# 3     14  2018-03  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10
# 4     14  2018-05  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10
#
#    floor_area_sqm flat_model  lease_commence_date     remaining_lease  \
# 0            44.0   Improved                 1979  61 years 04 months
# 1            44.0   Improved                 1979   61 years 01 month
# 2            44.0   Improved                 1979  60 years 02 months
# 3            44.0   Improved                 1979  60 years 02 months
# 4            44.0   Improved                 1979   60 years 01 month
#
#    resale_price  Postal  Latitude  Longitude  max_floor_lvl  height_index  \
# 0      232000.0  560406  1.362005  103.85388             12           4.0
# 1      235000.0  560406  1.362005  103.85388             12           4.0
# 2      202000.0  560406  1.362005  103.85388             12           1.0
# 3      210000.0  560406  1.362005  103.85388             12           1.0
# 4      220000.0  560406  1.362005  103.85388             12           3.0
#
#    Nearest_Station  Distance_to_MRT Station Name  IndexCopy
# 0               14              1.0   Ang Mo Kio         14
# 1               14              1.0   Ang Mo Kio         14
# 2               14              1.0   Ang Mo Kio         14
# 3               14              1.0   Ang Mo Kio         14
# 4               14              1.0   Ang Mo Kio         14

# %%
df_final = df_final.drop(columns = ["key_0", "Nearest_Station", "IndexCopy"])
df_final.tail()
# Out:
#           month         town flat_type block street_name  floor_area_sqm  \
# 134388  2021-10  BUKIT TIMAH    4 ROOM     3  QUEEN'S RD            91.0
# 134389  2021-10  BUKIT TIMAH    4 ROOM     3  QUEEN'S RD            91.0
# 134390  2022-03  BUKIT TIMAH    4 ROOM     3  QUEEN'S RD            91.0
# 134391  2022-06  BUKIT TIMAH    4 ROOM     3  QUEEN'S RD            91.0
# 134392  2022-07  BUKIT TIMAH    4 ROOM     3  QUEEN'S RD            91.0
#
#        flat_model  lease_commence_date     remaining_lease  resale_price  \
# 134388   Improved                 1974  51 years 07 months      550000.0
# 134389   Improved                 1974  51 years 06 months      483000.0
# 134390   Improved                 1974  51 years 02 months      580000.0
# 134391   Improved                 1974  50 years 10 months      528000.0
# 134392   Improved                 1974  50 years 10 months      560000.0
#
#         Postal  Latitude   Longitude  max_floor_lvl  height_index  \
# 134388  266734  1.322878  103.811648             12           4.0
# 134389  266734  1.322878  103.811648             12           2.0
# 134390  266734  1.322878  103.811648             12           2.0
# 134391  266734  1.322878  103.811648             12           2.0
# 134392  266734  1.322878  103.811648             12           3.0
#
#         Distance_to_MRT     Station Name
# 134388             0.42  Botanic Gardens
# 134389             0.42  Botanic Gardens
# 134390             0.42  Botanic Gardens
# 134391             0.42  Botanic Gardens
# 134392             0.42  Botanic Gardens

# %%
df_final.shape[0]
# Out:
# 134393

# %%
#df_final.to_csv("Resale_Data_Final_Cleaned.csv", index = False)
df_final = pd.read_csv("Resale_Data_Final_Cleaned.csv")

# %% [markdown]
# ---

# %% [markdown]
# ### Obtaining MRT Travel Duration

# %%
import requests
import time
import googlemaps

# %%
gmaps = googlemaps.Client(key="your-key")

# %%
df_mrt.head()
# Out:
#     Station Name  IndexCopy
# 0    Jurong East          0
# 1    Bukit Batok          1
# 2   Bukit Gombak          2
# 3  Choa Chu Kang          3
# 4        Yew Tee          4

# %%
duration_list = []
error_list = []
for station in df_mrt["Station Name"]:
    try:
        origin = station + " MRT"
        response = gmaps.distance_matrix(origins = origin, destinations = "City Hall MRT", mode = "transit", transit_mode = "rail", departure_time = "1667206800")
        #departure_time = 1667260800 is Unix timestamp and is required by the api to be set as current time or sometime in the future
        #1667260800 equates to Tue Nov 01 2022 08:00:00 GMT+0800 (Singapore Standard Time)
        duration = response["rows"][0]["elements"][0]["duration"]["text"]
        duration_list.append(duration)
        time.sleep(0.2)
    except:
        print("Error at", origin)
        error_list.append(origin)
        duration_list.append(None)
df_mrt["Duration"] = duration_list
df_mrt.head()
# Out:
# Error at City Hall MRT
# Error at HarbourFront MRT
# Error at Pasir Panjang MRT
# Error at Downtown MRT
#     Station Name  IndexCopy Duration
# 0    Jurong East          0  29 mins
# 1    Bukit Batok          1  40 mins
# 2   Bukit Gombak          2  41 mins
# 3  Choa Chu Kang          3  46 mins
# 4        Yew Tee          4  45 mins

# %%
error_list
# Out:
# ['City Hall MRT', 'HarbourFront MRT', 'Pasir Panjang MRT', 'Downtown MRT']

# %%
#Even when repeated, these stations do not receive a response from the API.
#Besides City Hall station (for which destination is same as origin), the reason for null response is not known.
#Using Google directions search, we obtain:
#Pasir Panjang = 34
#HarbourFront = 25
#Downtown = 13

# %%
pd.set_option('display.max_rows', 130)
df_mrt_duration = df_mrt.copy()
df_mrt_duration["Duration"] = duration_list
df_mrt_duration
# Out:
#           Station Name  IndexCopy       Duration
# 0          Jurong East          0        29 mins
# 1          Bukit Batok          1        40 mins
# 2         Bukit Gombak          2        41 mins
# 3        Choa Chu Kang          3        46 mins
# 4              Yew Tee          4        45 mins
# 5               Kranji          5        51 mins
# 6            Marsiling          6        48 mins
# 7            Woodlands          7        46 mins
# 8            Admiralty          8        42 mins
# 9            Sembawang          9        41 mins
# 10            Canberra         10        38 mins
# 11              Yishun         11        35 mins
# 12              Khatib         12        33 mins
# 13        Yio Chu Kang         13        26 mins
# 14          Ang Mo Kio         14        26 mins
# 15              Bishan         15        23 mins
# 16            Braddell         16        21 mins
# 17           Toa Payoh         17        21 mins
# 18              Novena         18        18 mins
# 19              Newton         19        14 mins
# 20             Orchard         20        14 mins
# 21            Somerset         21        12 mins
# 22         Dhoby Ghaut         22        11 mins
# 23           City Hall         23           None
# 24       Raffles Place         24         8 mins
# 25          Marina Bay         25        10 mins
# 26   Marina South Pier         26        12 mins
# 27           Pasir Ris         27        32 mins
# 28            Tampines         28        29 mins
# 29               Simei         29        30 mins
# 30         Tanah Merah         30        26 mins
# 31               Bedok         31        24 mins
# 32           Kembangan         32        22 mins
# 33               Eunos         33        20 mins
# 34          Paya Lebar         34        20 mins
# 35            Aljunied         35        17 mins
# 36             Kallang         36        15 mins
# 37            Lavender         37        11 mins
# 38               Bugis         38        11 mins
# 39       Tanjong Pagar         39        13 mins
# 40         Outram Park         40        17 mins
# 41         Tiong Bahru         41        16 mins
# 42             Redhill         42        18 mins
# 43          Queenstown         43        21 mins
# 44        Commonwealth         44        23 mins
# 45         Buona Vista         45        24 mins
# 46               Dover         46        26 mins
# 47            Clementi         47        28 mins
# 48      Chinese Garden         48        35 mins
# 49            Lakeside         49        37 mins
# 50            Boon Lay         50        39 mins
# 51             Pioneer         51        42 mins
# 52            Joo Koon         52        45 mins
# 53          Gul Circle         53        46 mins
# 54       Tuas Crescent         54        47 mins
# 55      Tuas West Road         55        48 mins
# 56           Tuas Link         56        50 mins
# 57                Expo         57        32 mins
# 58      Changi Airport         58        40 mins
# 59        HarbourFront         59           None
# 60           Chinatown         60        20 mins
# 61         Clarke Quay         61        11 mins
# 62        Little India         62        22 mins
# 63         Farrer Park         63        23 mins
# 64           Boon Keng         64        24 mins
# 65        Potong Pasir         65        27 mins
# 66           Woodleigh         66        28 mins
# 67           Serangoon         67        34 mins
# 68               Kovan         68        33 mins
# 69             Hougang         69        34 mins
# 70            Buangkok         70        33 mins
# 71            Sengkang         71        35 mins
# 72             Punggol         72        38 mins
# 73          Bras Basah         73         7 mins
# 74           Esplanade         74         5 mins
# 75           Promenade         75        16 mins
# 76      Nicoll Highway         76        17 mins
# 77             Stadium         77        25 mins
# 78         Mountbatten         78        25 mins
# 79              Dakota         79        24 mins
# 80          MacPherson         80        27 mins
# 81            Tai Seng         81        30 mins
# 82             Bartley         82        32 mins
# 83        Lorong Chuan         83        37 mins
# 84           Marymount         84        35 mins
# 85           Caldecott         85        32 mins
# 86     Botanic Gardens         86        28 mins
# 87         Farrer Road         87        37 mins
# 88     Holland Village         88        36 mins
# 89           one-north         89        35 mins
# 90          Kent Ridge         90        37 mins
# 91       Haw Par Villa         91        39 mins
# 92       Pasir Panjang         92           None
# 93       Labrador Park         93        40 mins
# 94       Telok Blangah         94        30 mins
# 95            Bayfront         95        23 mins
# 96       Bukit Panjang         96        40 mins
# 97              Cashew         97        38 mins
# 98            Hillview         98        36 mins
# 99        Beauty World         99        32 mins
# 100   King Albert Park        100        34 mins
# 101       Sixth Avenue        101        31 mins
# 102        Tan Kah Kee        102        30 mins
# 103            Stevens        103        26 mins
# 104             Rochor        104        18 mins
# 105           Downtown        105           None
# 106         Telok Ayer        106        13 mins
# 107       Fort Canning        107        15 mins
# 108          Bencoolen        108        11 mins
# 109        Jalan Besar        109        18 mins
# 110          Bendemeer        110        22 mins
# 111      Geylang Bahru        111        23 mins
# 112             Mattar        112        28 mins
# 113                Ubi        113        31 mins
# 114         Kaki Bukit        114        33 mins
# 115        Bedok North        115        34 mins
# 116    Bedok Reservoir        116        37 mins
# 117      Tampines West        117        41 mins
# 118      Tampines East        118        40 mins
# 119       Upper Changi        119        43 mins
# 120    Woodlands North        120        59 mins
# 121    Woodlands South        121  1 hour 0 mins

# %%
df_mrt_duration.loc[(df_mrt_duration["Station Name"] == "City Hall"), "Duration"] = "0 mins"
df_mrt_duration.loc[(df_mrt_duration["Station Name"] == "HarbourFront"), "Duration"] = "22 mins"
df_mrt_duration.loc[(df_mrt_duration["Station Name"] == "Pasir Panjang"), "Duration"] = "36 mins"
df_mrt_duration.loc[(df_mrt_duration["Station Name"] == "Downtown"), "Duration"] = "15 mins"
df_mrt_duration.loc[(df_mrt_duration["Station Name"] == "Woodlands South"), "Duration"] = "60 mins"

# %%
df_mrt_duration = df_mrt_duration.drop(columns = ["IndexCopy"])

# %%
#df_mrt_duration.to_csv("MRT_Duration.csv", index = False)
df_mrt_duration = pd.read_csv("MRT_Duration.csv")

# %% [markdown]
# ---

# %% [markdown]
# ### Merging Main DataFrame with Travel Duration

# %%
df_marged_with_duration = df_final.merge(df_mrt_duration, left_on= df_final["Station Name"], right_on= df_mrt_duration["Station Name"])
df_marged_with_duration.head()
# Out:
#         key_0    month        town flat_type block        street_name  \
# 0  Ang Mo Kio  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10
# 1  Ang Mo Kio  2017-05  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10
# 2  Ang Mo Kio  2018-03  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10
# 3  Ang Mo Kio  2018-03  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10
# 4  Ang Mo Kio  2018-05  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10
#
#    floor_area_sqm flat_model  lease_commence_date     remaining_lease  \
# 0            44.0   Improved                 1979  61 years 04 months
# 1            44.0   Improved                 1979   61 years 01 month
# 2            44.0   Improved                 1979  60 years 02 months
# 3            44.0   Improved                 1979  60 years 02 months
# 4            44.0   Improved                 1979   60 years 01 month
#
#    resale_price  Postal  Latitude  Longitude  max_floor_lvl  height_index  \
# 0      232000.0  560406  1.362005  103.85388             12           4.0
# 1      235000.0  560406  1.362005  103.85388             12           4.0
# 2      202000.0  560406  1.362005  103.85388             12           1.0
# 3      210000.0  560406  1.362005  103.85388             12           1.0
# 4      220000.0  560406  1.362005  103.85388             12           3.0
#
#    Distance_to_MRT Station Name_x Station Name_y Duration
# 0              1.0     Ang Mo Kio     Ang Mo Kio  26 mins
# 1              1.0     Ang Mo Kio     Ang Mo Kio  26 mins
# 2              1.0     Ang Mo Kio     Ang Mo Kio  26 mins
# 3              1.0     Ang Mo Kio     Ang Mo Kio  26 mins
# 4              1.0     Ang Mo Kio     Ang Mo Kio  26 mins

# %%
df_marged_with_duration.shape[0]
# Out:
# 134393

# %%
df_marged_with_duration = df_marged_with_duration.drop(columns = ["key_0", "Station Name_y"])
df_marged_with_duration = df_marged_with_duration.rename(columns = {"month": "resale_date", "Station Name_x": "station_name", "Duration": "travel_time" })
df_marged_with_duration.head()
# Out:
#   resale_date        town flat_type block        street_name  floor_area_sqm  \
# 0     2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10            44.0
# 1     2017-05  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10            44.0
# 2     2018-03  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10            44.0
# 3     2018-03  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10            44.0
# 4     2018-05  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10            44.0
#
#   flat_model  lease_commence_date     remaining_lease  resale_price  Postal  \
# 0   Improved                 1979  61 years 04 months      232000.0  560406
# 1   Improved                 1979   61 years 01 month      235000.0  560406
# 2   Improved                 1979  60 years 02 months      202000.0  560406
# 3   Improved                 1979  60 years 02 months      210000.0  560406
# 4   Improved                 1979   60 years 01 month      220000.0  560406
#
#    Latitude  Longitude  max_floor_lvl  height_index  Distance_to_MRT  \
# 0  1.362005  103.85388             12           4.0              1.0
# 1  1.362005  103.85388             12           4.0              1.0
# 2  1.362005  103.85388             12           1.0              1.0
# 3  1.362005  103.85388             12           1.0              1.0
# 4  1.362005  103.85388             12           3.0              1.0
#
#   station_name travel_time
# 0   Ang Mo Kio     26 mins
# 1   Ang Mo Kio     26 mins
# 2   Ang Mo Kio     26 mins
# 3   Ang Mo Kio     26 mins
# 4   Ang Mo Kio     26 mins

# %%
df_marged_with_duration.to_csv("Resale_Data_with_travel_duration.csv", index = False)
